# %%
import numpy as np
import torch
from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import transforms
from FreeFormDeformation import DeformationLayer
from deepali.core import functional as U
from tqdm import tqdm
import random
from diffusion_unet import Unet
from torch import nn, optim
import os
import cv2
from torch.cuda.amp import GradScaler, autocast
from PIL import Image
import torchvision.transforms.functional as F

# %%
class CustomDataset(Dataset):
    def __init__(self, image_paths, transform=None, device = "cpu"):
        """
        Args:
            image_paths (list): List of all image Paths.
            shape: The shape of one image in the dataset.
            mean (float): The mean value for normalization.
            std (float): The standard deviation for normalization.
            transform (bool): Whether to apply the transformation.
        """
        self.image_paths = image_paths
        self.transform = transform
        self.device = device
    
    def __len__(self):
        return len(self.image_paths)
    
    def build_deformation_layer(self, shape, device):
        """
        Build and return a new deformation layer for each call to __getitem__.
        This method returns the created deformation layer.
        """
        deformation_layer = DeformationLayer(shape)
        deformation_layer.new_deformation(device=device)
        return deformation_layer

    def __getitem__(self, idx):
        # Fetch the original image
        image_path = self.image_paths[idx]
        img = cv2.imread(image_path)
        if img is None:
            raise FileNotFoundError(f"Image not found at path: {image_path}")
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = Image.fromarray(img)
        transform = transforms.Resize((256,256))
        img = transform(img)
        img = F.pil_to_tensor(img).float().to(self.device)
        print("imgshape",img.shape)
        shape = img.squeeze(0).shape
        #shape = shape.to(self.device)
        print("squeeze shape", shape)
        #original_image = img.unsqueeze(0)  # Add batch dimension
        original_image= img.to(self.device)
        

        # Build a new deformation layer for the current image
        deformation_layer = self.build_deformation_layer(shape, self.device).to(self.device)

        # Apply deformation to get the deformed image
        deformed_image = deformation_layer.deform(original_image).to(self.device)
        # Fetch the current deformation field
        deformation_field = deformation_layer.get_deformation_field().squeeze(0).to(self.device)
        
        # transform the images
        if self.transform:
            original_image = self.transform(original_image)
            deformed_image = self.transform(deformed_image)

        # Stack the original and deformed images along the channel dimension
        stacked_image = torch.cat([original_image, deformed_image], dim=0).squeeze(0)

        return stacked_image, deformation_field

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, n_epochs, device):
    scaler = GradScaler()  # Initialize the GradScaler for mixed precision training
    
    for epoch in range(n_epochs):
        model.train()
        train_loss = 0
        print(111)
        
        for i, (images, deformation_field) in enumerate(train_loader):
            print(1211)
            images = images.float().to(device)
            deformation_field = deformation_field.to(device)

            print(images.shape)
            print(deformation_field.shape)

            
            optimizer.zero_grad()

            # Use autocast for mixed precision
            with autocast():
                outputs = model(images)
                loss = criterion(outputs, deformation_field)
                train_loss += loss.item()

            # Backward pass with scaled loss
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

        avg_train_loss = train_loss / len(train_loader)
        
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for i, (images, deformation_field) in enumerate(val_loader):
                images = images.float().to(device)
                deformation_field = deformation_field.to(device)
                print(images.shape)
                print(deformation_field.shape)
                # Use autocast for mixed precision
                with autocast():
                    outputs = model(images)
                    batch_loss = criterion(outputs, deformation_field).item()
                    val_loss += batch_loss
            
            avg_val_loss = val_loss / len(val_loader)
            
            print(f'Training Loss (Epoch {epoch+1}/{n_epochs}): {avg_train_loss:.4f}')
            print(f'Validation Loss (Epoch {epoch+1}/{n_epochs}): {avg_val_loss:.4f}')

# %%
def get_image_paths(root_dir): 
    
    image_paths = []
    for category in os.listdir(root_dir):
        category_dir = os.path.join(root_dir, category)
        if os.path.isdir(category_dir):
            for filename in os.listdir(category_dir):
                if filename.endswith(".jpg") or filename.endswith(".png"):
                    image_paths.append(os.path.join(category_dir, filename))   
    return image_paths

# %%
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    train_data_path = '/home/ubuntu/ADLM/data/high-resolution/afhq/train'
    val_data_path = '/home/ubuntu/ADLM/data/high-resolution/afhq/val'

    train_images_paths = get_image_paths(train_data_path)
    val_images_paths = get_image_paths(val_data_path)
    
    mean = 0.5
    std = 0.5
    
    train_dataset = CustomDataset(train_images_paths, transform=transforms.Compose([transforms.Normalize(mean=[mean], std=[std])]), device=device)
    val_dataset = CustomDataset(val_images_paths, transform=transforms.Compose([transforms.Normalize(mean=[mean], std=[std])]), device=device)
    train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=16, shuffle=True)

    model = Unet(
        dim=8,
        init_dim=None,
        out_dim=2,
        dim_mults=(1, 2, 4, 8),
        channels=2,
        resnet_block_groups=8,
        learned_variance=False,
        conditional_dimensions=0,
        patch_size=1,
        attention_layer=None
    )

    model.to(device)
    # Check if weights file exists
   

    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

    n_epochs = 5
    train_model(model, train_loader, val_loader, criterion, optimizer, n_epochs, device)
    
    # save (update the number of epochs in name)
# Out:
# Attention lvl 0 8 8
# Attention lvl 1 8 16
# Attention lvl 2 16 32
# Attention lvl 3 32 64
# 111
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# imgshape torch.Size([1, 256, 256])
# squeeze shape torch.Size([256, 256])
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[47], line 38
#      35 optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
#      37 n_epochs = 5
# ---> 38 train_model(model, train_loader, val_loader, criterion, optimizer, n_epochs, device)
#
# Cell In[45], line 9, in train_model(model, train_loader, val_loader, criterion, optimizer, n_epochs, device)
#       6 train_loss = 0
#       7 print(111)
# ----> 9 for i, (images, deformation_field) in enumerate(train_loader):
#      10     print(1211)
#      11     images = images.float().to(device)
#
# File ~/miniconda3/envs/adlm1/lib/python3.12/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniconda3/envs/adlm1/lib/python3.12/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/miniconda3/envs/adlm1/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File ~/miniconda3/envs/adlm1/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:316, in default_collate(batch)
#     255 def default_collate(batch):
#     256     r"""
#     257     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     258
#    (...)
#     314         >>> default_collate(batch)  # Handle `CustomType` automatically
#     315     """
# --> 316     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~/miniconda3/envs/adlm1/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:173, in collate(batch, collate_fn_map)
#     170 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     172 if isinstance(elem, tuple):
# --> 173     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     174 else:
#     175     try:
#
# File ~/miniconda3/envs/adlm1/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:141, in collate(batch, collate_fn_map)
#     139 if collate_fn_map is not None:
#     140     if elem_type in collate_fn_map:
# --> 141         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     143     for collate_type in collate_fn_map:
#     144         if isinstance(elem, collate_type):
#
# File ~/miniconda3/envs/adlm1/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:213, in collate_tensor_fn(batch, collate_fn_map)
#     211     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     212     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 213 return torch.stack(batch, 0, out=out)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU

# %%
import os
import random
import shutil

def reduce_images_in_folder(folder_path, fraction=1/3):
    for subdir, _, files in os.walk(folder_path):
        if files:
            num_files_to_keep = max(1, int(len(files) * fraction))
            files_to_keep = random.sample(files, num_files_to_keep)
            files_to_remove = set(files) - set(files_to_keep)
            
            for file_name in files_to_remove:
                file_path = os.path.join(subdir, file_name)
                os.remove(file_path)
                print(f"Removed {file_path}")

def main():
    base_path = '/home/ubuntu/ADLM/data/high-resolution/afhq'
    train_path = os.path.join(base_path, 'train')
    val_path = os.path.join(base_path, 'val')
    
    # Reduce images in train and val folders
    reduce_images_in_folder(train_path, fraction=1/3)
    reduce_images_in_folder(val_path, fraction=1/3)
    
if __name__ == "__main__":
    main()
# Out:
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002695.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002502.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001669.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003321.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001395.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003146.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002615.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002369.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001724.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002920.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002209.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000292.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001047.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001439.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_004041.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003732.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001355.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000840.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001252.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001237.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000506.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001070.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003282.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000210.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003696.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002731.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000399.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002850.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000869.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002351.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000221.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000141.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001986.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003077.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000519.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003104.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000377.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003500.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001599.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002095.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001161.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001745.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000158.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001635.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000035.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000712.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000677.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002029.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000232.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002458.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001280.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003187.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000618.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000728.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001039.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000258.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001803.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000683.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001938.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003514.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001371.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002791.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002975.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003786.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000387.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001987.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001534.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003609.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000428.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001060.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001933.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002320.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003399.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001146.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001342.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001518.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001295.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001022.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000134.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000204.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001744.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002303.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001147.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002432.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002707.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000155.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002024.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001831.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000136.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000751.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002572.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000525.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000628.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000305.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000347.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001275.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000459.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001286.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000150.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003432.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002429.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000947.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000520.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001187.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000055.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000349.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001597.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000632.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001007.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000532.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002919.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000975.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001761.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003184.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002059.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002327.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003413.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001045.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003214.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002105.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000779.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001952.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002876.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003821.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002256.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003661.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001163.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003018.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001995.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000912.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000360.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000504.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002032.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_004001.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000225.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003365.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000899.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002959.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000021.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000026.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000436.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003464.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002960.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001440.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002165.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000316.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003857.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000893.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002322.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003831.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002461.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001619.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001516.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001441.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000869.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000844.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000718.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003145.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003900.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001263.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001066.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000683.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000603.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000207.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000876.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000498.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003263.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001046.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001089.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003459.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002056.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003850.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003206.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003995.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002483.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001376.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000318.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000275.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000364.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002787.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001165.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000172.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000047.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003266.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001870.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003005.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003195.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002789.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002280.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003568.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001365.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000312.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001841.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002686.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000193.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000531.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000386.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002633.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000546.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_004012.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002182.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003289.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000130.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000043.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002265.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001257.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002146.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001180.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003668.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002810.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000506.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003665.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000256.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001061.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003581.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000749.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002048.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003641.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000195.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000901.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000545.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000797.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000018.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000055.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000320.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003613.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001749.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001108.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003878.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001092.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003106.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003212.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000907.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000323.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001314.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003479.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000692.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002886.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003348.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000539.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000463.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_004035.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003768.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000990.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001766.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000456.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001262.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000263.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000859.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000735.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003594.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001005.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002697.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003934.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000924.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001075.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001755.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000719.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000970.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003097.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002576.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000208.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001203.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002679.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000980.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000626.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001578.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003336.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000379.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002425.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000762.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000238.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002981.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002923.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000041.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000299.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002585.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001003.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_004002.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000942.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003525.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000376.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000855.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000663.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000072.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003673.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000951.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003453.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000341.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001533.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003739.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000570.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000621.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000325.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000968.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003736.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002189.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000930.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000164.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000803.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000269.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001668.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003373.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001422.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000302.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000462.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001478.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000229.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003872.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003724.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001616.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000379.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002568.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000931.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000185.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000383.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000033.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002049.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001091.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001392.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002227.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000486.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003378.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001694.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002795.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001807.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001863.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003397.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002847.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001813.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001132.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000008.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003580.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002324.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002392.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000898.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003555.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002966.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000913.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002442.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000458.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001905.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002639.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003160.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003691.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000773.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001720.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000872.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003168.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001871.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002660.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000020.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003912.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000419.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000191.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000953.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001512.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002719.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002014.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000014.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000137.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003583.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000644.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002371.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000968.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000308.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002828.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001955.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001136.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003675.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003224.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002835.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000648.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002637.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000319.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000923.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003354.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003364.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000750.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001108.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003779.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002023.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000523.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003700.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000627.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003234.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003430.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001141.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001170.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001003.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002715.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000831.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001065.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000685.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003508.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000435.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001002.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002018.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002386.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000048.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001181.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001778.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000358.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000102.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000669.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001062.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003603.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003400.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000100.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000674.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001258.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003573.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002646.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003208.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000674.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001886.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003134.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002494.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000722.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002064.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001017.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000296.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002995.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000587.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000493.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003533.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003530.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000649.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003682.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003550.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000991.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000756.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002741.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002268.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000285.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003272.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000816.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000394.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001467.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001701.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001679.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002635.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002246.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000446.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002991.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002931.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001113.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000219.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001848.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002993.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002758.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000038.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003081.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000119.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000050.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001942.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001056.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000970.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000906.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000401.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001158.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003277.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003260.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000583.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001708.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000761.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001268.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000019.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000195.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001086.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003011.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000796.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003019.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002542.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003899.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001865.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001862.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000156.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001935.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003620.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002328.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001921.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001391.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002103.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003820.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000801.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000002.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002130.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001127.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001902.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003977.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000084.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000264.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000681.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000314.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001270.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001612.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003202.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001876.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001133.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_004028.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003472.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000011.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_001044.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000937.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003451.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000697.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000662.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000381.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002114.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003590.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002415.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000620.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001762.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000349.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000516.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000769.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000395.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000463.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000513.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000078.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000781.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000116.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001469.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000287.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000511.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003455.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002663.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000170.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000783.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001823.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003526.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000292.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001310.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000149.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000355.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000431.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002241.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003087.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003695.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002187.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002422.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002222.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003560.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001079.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002773.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000254.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001731.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000129.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001261.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002141.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002832.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000830.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003186.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002412.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002716.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003699.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000699.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000866.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/flickr_dog_000203.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_002229.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_003237.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001343.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001111.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_001202.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/train/dog/pixabay_dog_000532.jpg
# ...
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_003000.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001144.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004685.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004337.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_003964.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/flickr_cat_000514.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000392.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004625.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/flickr_cat_000614.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/flickr_cat_000183.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004505.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000730.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001997.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_002798.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000147.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001287.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001729.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_002749.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_002510.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_002441.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001405.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001348.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_003556.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004461.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_003524.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/flickr_cat_000526.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/flickr_cat_000535.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001599.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000151.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004379.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001727.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/flickr_cat_000802.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001699.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000542.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004652.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004092.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/flickr_cat_000341.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_003820.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/flickr_cat_000238.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001179.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004415.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_002890.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_003483.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004601.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001536.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_003931.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000248.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001635.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004808.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_002543.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000010.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004422.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001974.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000700.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_003742.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_002138.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_002467.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_003392.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004102.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004759.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_002155.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000889.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000696.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/flickr_cat_000709.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000126.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004189.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004484.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_003924.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000441.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000514.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001465.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_002129.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_001724.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/flickr_cat_000554.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_002269.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_003464.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000302.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_000051.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/flickr_cat_000608.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/cat/pixabay_cat_004044.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002553.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001945.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000526.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001223.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000637.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000375.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000557.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000144.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003970.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001892.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000106.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000814.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001088.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003823.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002874.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002030.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000147.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002946.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000988.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000584.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003246.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002259.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003355.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002942.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000598.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000966.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003924.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003854.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000099.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000022.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000599.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003498.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000833.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001552.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001547.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002948.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003710.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003761.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000535.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003130.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002182.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002614.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000133.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001587.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001711.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000373.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000420.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000574.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003357.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002124.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000356.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000418.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000732.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001436.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003796.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000012.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002933.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000382.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000564.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001843.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001258.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003777.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003943.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000281.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000920.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001627.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_001112.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002138.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003331.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_001115.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000729.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001598.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001941.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003238.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000771.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000361.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002886.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_001134.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002319.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000840.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003773.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003085.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002093.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002914.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000604.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002747.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002461.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001927.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000129.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001211.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000411.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002558.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003918.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001619.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002545.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000286.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001329.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000864.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000418.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000613.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002159.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002926.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000535.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_001001.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_002250.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000302.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_003849.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000711.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_000306.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/pixabay_wild_000274.jpg
# Removed /home/ubuntu/ADLM/data/high-resolution/afhq/val/wild/flickr_wild_001096.jpg

# %%
import os

def count_images_in_folder(folder_path):
    # 获取文件夹中的所有文件
    files = os.listdir(folder_path)
    
    # 过滤掉非图片文件（假设所有图片文件都是常见的图片格式，如jpg, png, jpeg, bmp, gif等）
    image_extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.gif'}
    image_files = [file for file in files if os.path.splitext(file)[1].lower() in image_extensions]
    
    # 打印图片数量
    print(f"Total number of images in '{folder_path}': {len(image_files)}")

# 文件夹路径
folder_path = '/home/ubuntu/ADLM/data/high-resolution/afhq/train/cat'

# 调用函数并输出结果
count_images_in_folder(folder_path)
# Out:
# Total number of images in '/home/ubuntu/ADLM/data/high-resolution/afhq/train/cat': 572
